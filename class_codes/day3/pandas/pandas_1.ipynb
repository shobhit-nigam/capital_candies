# %%
import pandas as pd

# %%
dfa = pd.read_csv("annual.csv")

# %%
dfa.shape
# Out:
# (41715, 10)

# %%
dfa
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# 4                  All industries  Dollars (millions)           H08
# ...                           ...                 ...           ...
# 41710  Food product manufacturing          Percentage           H37
# 41711  Food product manufacturing          Percentage           H38
# 41712  Food product manufacturing          Percentage           H39
# 41713  Food product manufacturing          Percentage           H40
# 41714  Food product manufacturing          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 41710                                      Quick ratio       Financial ratios
# 41711              Margin on sales of goods for resale       Financial ratios
# 41712                                 Return on equity       Financial ratios
# 41713                           Return on total assets       Financial ratios
# 41714                            Liabilities structure       Financial ratios
#
#          Value                             Industry_code_ANZSIC06
# 0      757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1      674,890  ANZSIC06 divisions A-S (excluding classes K633...
# 2       49,593  ANZSIC06 divisions A-S (excluding classes K633...
# 3       33,020  ANZSIC06 divisions A-S (excluding classes K633...
# 4      654,404  ANZSIC06 divisions A-S (excluding classes K633...
# ...        ...                                                ...
# 41710       52  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41711       40  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41712       12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41713        5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41714       46  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [41715 rows x 10 columns]

# %%
dfa.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41715 entries, 0 to 41714
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         41715 non-null  int64
#  1   Industry_aggregation_NZSIOC  41715 non-null  object
#  2   Industry_code_NZSIOC         41715 non-null  object
#  3   Industry_name_NZSIOC         41715 non-null  object
#  4   Units                        41715 non-null  object
#  5   Variable_code                41715 non-null  object
#  6   Variable_name                41715 non-null  object
#  7   Variable_category            41715 non-null  object
#  8   Value                        41715 non-null  object
#  9   Industry_code_ANZSIC06       41715 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.2+ MB

# %%
dfa['Industry_aggregation_NZSIOC'].nunique()
# Out:
# 3

# %%
dfa['Industry_aggregation_NZSIOC'].unique()
# Out:
# array(['Level 1', 'Level 3', 'Level 4'], dtype=object)

# %%
dfa['Industry_aggregation_NZSIOC'].value_counts()
# Out:
# Level 4    22833
# Level 3    13851
# Level 1     5031
# Name: Industry_aggregation_NZSIOC, dtype: int64

# %%
# dfa['Industry_aggregation_NZSIOC'] == 'Level 1'

dfa [ dfa['Industry_aggregation_NZSIOC'] == 'Level 1' ]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41418  2013                     Level 1                   RS
# 41419  2013                     Level 1                   RS
# 41420  2013                     Level 1                   RS
# 41421  2013                     Level 1                   RS
# 41422  2013                     Level 1                   RS
#
#                       Industry_name_NZSIOC               Units Variable_code  \
# 0                           All industries  Dollars (millions)           H01
# 1                           All industries  Dollars (millions)           H04
# 2                           All industries  Dollars (millions)           H05
# 3                           All industries  Dollars (millions)           H07
# 4                           All industries  Dollars (millions)           H08
# ...                                    ...                 ...           ...
# 41418  Arts, Recreation and Other Services          Percentage           H36
# 41419  Arts, Recreation and Other Services          Percentage           H37
# 41420  Arts, Recreation and Other Services          Percentage           H39
# 41421  Arts, Recreation and Other Services          Percentage           H40
# 41422  Arts, Recreation and Other Services          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 41418                                    Current ratio       Financial ratios
# 41419                                      Quick ratio       Financial ratios
# 41420                                 Return on equity       Financial ratios
# 41421                           Return on total assets       Financial ratios
# 41422                            Liabilities structure       Financial ratios
#
#          Value                             Industry_code_ANZSIC06
# 0      757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1      674,890  ANZSIC06 divisions A-S (excluding classes K633...
# 2       49,593  ANZSIC06 divisions A-S (excluding classes K633...
# 3       33,020  ANZSIC06 divisions A-S (excluding classes K633...
# 4      654,404  ANZSIC06 divisions A-S (excluding classes K633...
# ...        ...                                                ...
# 41418      147                         ANZSIC06 divisions R and S
# 41419      137                         ANZSIC06 divisions R and S
# 41420       14                         ANZSIC06 divisions R and S
# 41421        9                         ANZSIC06 divisions R and S
# 41422       69                         ANZSIC06 divisions R and S
#
# [5031 rows x 10 columns]

# %%
dfa_1 = dfa [ dfa['Industry_aggregation_NZSIOC'] == 'Level 1' ]

# %%
dfa_1.to_excel("level 1.xlsx", index=False)

# %%
dfa[11:30]
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 11  2021                     Level 1                99999
# 12  2021                     Level 1                99999
# 13  2021                     Level 1                99999
# 14  2021                     Level 1                99999
# 15  2021                     Level 1                99999
# 16  2021                     Level 1                99999
# 17  2021                     Level 1                99999
# 18  2021                     Level 1                99999
# 19  2021                     Level 1                99999
# 20  2021                     Level 1                99999
# 21  2021                     Level 1                99999
# 22  2021                     Level 1                99999
# 23  2021                     Level 1                99999
# 24  2021                     Level 1                99999
# 25  2021                     Level 1                99999
# 26  2021                     Level 1                99999
# 27  2021                     Level 1                99999
# 28  2021                     Level 1                99999
# 29  2021                     Level 1                99999
#
#    Industry_name_NZSIOC               Units Variable_code  \
# 11       All industries  Dollars (millions)           H19
# 12       All industries  Dollars (millions)           H20
# 13       All industries  Dollars (millions)           H21
# 14       All industries  Dollars (millions)           H22
# 15       All industries  Dollars (millions)           H23
# 16       All industries  Dollars (millions)           H24
# 17       All industries  Dollars (millions)           H25
# 18       All industries  Dollars (millions)           H26
# 19       All industries  Dollars (millions)           H29
# 20       All industries  Dollars (millions)           H30
# 21       All industries  Dollars (millions)           H31
# 22       All industries  Dollars (millions)           H32
# 23       All industries  Dollars (millions)           H33
# 24       All industries             Dollars           H34
# 25       All industries             Dollars           H35
# 26       All industries          Percentage           H36
# 27       All industries          Percentage           H37
# 28       All industries          Percentage           H39
# 29       All industries          Percentage           H40
#
#                              Variable_name      Variable_category      Value  \
# 11  Purchases and other operating expenses  Financial performance    452,963
# 12                  Non-operating expenses  Financial performance     14,806
# 13                          Opening stocks  Financial performance     68,896
# 14                          Closing stocks  Financial performance     69,127
# 15               Surplus before income tax  Financial performance    103,330
# 16                            Total assets     Financial position  2,512,677
# 17                          Current assets     Financial position    730,587
# 18                   Fixed tangible assets     Financial position    591,351
# 19                            Other assets     Financial position  1,190,739
# 20            Total equity and liabilities     Financial position  2,512,677
# 21     Shareholders funds or owners equity     Financial position    813,949
# 22                     Current liabilities     Financial position    933,093
# 23                       Other liabilities     Financial position    765,635
# 24         Total income per employee count       Financial ratios    400,900
# 25              Surplus per employee count       Financial ratios     54,700
# 26                           Current ratio       Financial ratios         78
# 27                             Quick ratio       Financial ratios         71
# 28                        Return on equity       Financial ratios         13
# 29                  Return on total assets       Financial ratios          4
#
#                                Industry_code_ANZSIC06
# 11  ANZSIC06 divisions A-S (excluding classes K633...
# 12  ANZSIC06 divisions A-S (excluding classes K633...
# 13  ANZSIC06 divisions A-S (excluding classes K633...
# 14  ANZSIC06 divisions A-S (excluding classes K633...
# 15  ANZSIC06 divisions A-S (excluding classes K633...
# 16  ANZSIC06 divisions A-S (excluding classes K633...
# 17  ANZSIC06 divisions A-S (excluding classes K633...
# 18  ANZSIC06 divisions A-S (excluding classes K633...
# 19  ANZSIC06 divisions A-S (excluding classes K633...
# 20  ANZSIC06 divisions A-S (excluding classes K633...
# 21  ANZSIC06 divisions A-S (excluding classes K633...
# 22  ANZSIC06 divisions A-S (excluding classes K633...
# 23  ANZSIC06 divisions A-S (excluding classes K633...
# 24  ANZSIC06 divisions A-S (excluding classes K633...
# 25  ANZSIC06 divisions A-S (excluding classes K633...
# 26  ANZSIC06 divisions A-S (excluding classes K633...
# 27  ANZSIC06 divisions A-S (excluding classes K633...
# 28  ANZSIC06 divisions A-S (excluding classes K633...
# 29  ANZSIC06 divisions A-S (excluding classes K633...

# %%
dfa['Units'].value_counts()
# Out:
# Dollars (millions)    32796
# Percentage             6633
# Dollars                2286
# Name: Units, dtype: int64

# %%
help(dfa.value_counts)
# Out:
# Help on method value_counts in module pandas.core.frame:
#
# value_counts(subset: 'Optional[Sequence[Label]]' = None, normalize: 'bool' = False, sort: 'bool' = True, ascending: 'bool' = False) method of pandas.core.frame.DataFrame instance
#     Return a Series containing counts of unique rows in the DataFrame.
#
#     .. versionadded:: 1.1.0
#
#     Parameters
#     ----------
#     subset : list-like, optional
#         Columns to use when counting unique combinations.
#     normalize : bool, default False
#         Return proportions rather than frequencies.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#
#     Returns
#     -------
#     Series
#
#     See Also
#     --------
#     Series.value_counts: Equivalent method on Series.
#
#     Notes
#     -----
#     The returned Series will have a MultiIndex with one level per input
#     column. By default, rows that contain any NA values are omitted from
#     the result. By default, the resulting Series will be in descending
#     order so that the first element is the most frequently-occurring row.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'num_legs': [2, 4, 4, 6],
#     ...                    'num_wings': [2, 0, 0, 0]},
#     ...                   index=['falcon', 'dog', 'cat', 'ant'])
#     >>> df
#             num_legs  num_wings
#     falcon         2          2
#     dog            4          0
#     cat            4          0
#     ant            6          0
#
#     >>> df.value_counts()
#     num_legs  num_wings
#     4         0            2
#     2         2            1
#     6         0            1
#     dtype: int64
#
#     >>> df.value_counts(sort=False)
#     num_legs  num_wings
#     2         2            1
#     4         0            2
#     6         0            1
#     dtype: int64
#
#     >>> df.value_counts(ascending=True)
#     num_legs  num_wings
#     2         2            1
#     6         0            1
#     4         0            2
#     dtype: int64
#
#     >>> df.value_counts(normalize=True)
#     num_legs  num_wings
#     4         0            0.50
#     2         2            0.25
#     6         0            0.25
#     dtype: float64
